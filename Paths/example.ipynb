# %%
push!(LOAD_PATH, pwd())

# %%
using Paths, PyPlot, LinearAlgebra
# Out:
# ┌ Info: Precompiling Paths [top-level]
# └ @ Base loading.jl:1260

# %%
dims = (51,50)
space = propagate(dims)
matshow(abs.(space).^2, cmap="viridis")
# Out:
# Figure(PyObject <Figure size 470.588x480 with 1 Axes>)
# PyObject <matplotlib.image.AxesImage object at 0x1455e23d0>
